# %% [markdown]
# # Federated CARLA with Director example

# %%
# install requirements
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==1.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: anyio==3.6.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: argon2-cffi==21.3.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: asttokens==2.0.5 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (2.0.5)
# Requirement already satisfied: astunparse==1.6.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: attrs==21.4.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (21.4.0)
# Requirement already satisfied: auditwheel==5.1.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (5.1.2)
# Requirement already satisfied: Babel==2.10.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (2.10.1)
# Requirement already satisfied: backcall==0.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.11.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (4.11.1)
# Requirement already satisfied: bleach==5.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (5.0.0)
# Requirement already satisfied: cachetools==5.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (5.1.0)
# Requirement already satisfied: certifi==2022.5.18.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (2022.5.18.1)
# Requirement already satisfied: cffi==1.15.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (1.15.0)
# Requirement already satisfied: charset-normalizer==2.0.12 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (2.0.12)
# Requirement already satisfied: clang==5.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (5.0)
# Requirement already satisfied: click==8.0.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (8.0.1)
# Requirement already satisfied: cloudpickle==2.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (2.1.0)
# Requirement already satisfied: colorama==0.4.5 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (0.4.5)
# Requirement already satisfied: commonmark==0.9.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (0.9.1)
# Requirement already satisfied: contextlib2==21.6.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 22)) (21.6.0)
# Requirement already satisfied: cryptography==37.0.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (37.0.2)
# Requirement already satisfied: cycler==0.11.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 24)) (0.11.0)
# Requirement already satisfied: Cython==0.29.30 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (0.29.30)
# Requirement already satisfied: debugpy==1.6.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (1.6.0)
# Requirement already satisfied: decorator==5.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 28)) (0.7.1)
# Requirement already satisfied: dill==0.3.5.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (0.3.5.1)
# Requirement already satisfied: dm-tree==0.1.7 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (0.1.7)
# Requirement already satisfied: docker==5.0.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 31)) (5.0.3)
# Requirement already satisfied: docutils==0.18.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (0.18.1)
# Requirement already satisfied: dynaconf==3.1.7 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 33)) (3.1.7)
# Requirement already satisfied: entrypoints==0.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (0.4)
# Requirement already satisfied: etils==0.6.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (0.6.0)
# Requirement already satisfied: executing==0.8.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (0.8.3)
# Requirement already satisfied: fastjsonschema==2.15.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (2.15.3)
# Requirement already satisfied: filelock==3.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (3.7.1)
# Requirement already satisfied: flatbuffers==1.12 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (1.12)
# Requirement already satisfied: flatten-json==0.1.13 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 40)) (0.1.13)
# Requirement already satisfied: fonttools==4.33.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (4.33.3)
# Requirement already satisfied: gast==0.4.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (0.4.0)
# Requirement already satisfied: gdown==3.13.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (3.13.0)
# Requirement already satisfied: gin-config==0.5.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (0.5.0)
# Requirement already satisfied: google-api-core==2.8.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (2.8.2)
# Requirement already satisfied: google-api-python-client==2.52.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (2.52.0)
# Requirement already satisfied: google-auth==2.6.6 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.6.6)
# Requirement already satisfied: google-auth-httplib2==0.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (0.1.0)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 49)) (0.4.6)
# Requirement already satisfied: google-pasta==0.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (0.2.0)
# Requirement already satisfied: googleapis-common-protos==1.56.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (1.56.3)
# Requirement already satisfied: grpcio==1.34.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (1.34.0)
# Requirement already satisfied: h5py==3.7.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 53)) (3.7.0)
# Requirement already satisfied: httplib2==0.20.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (0.20.4)
# Requirement already satisfied: idna==3.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (3.3)
# Requirement already satisfied: imageio==2.19.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (2.19.3)
# Requirement already satisfied: imgaug==0.4.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 57)) (0.4.0)
# Requirement already satisfied: importlib-metadata==4.11.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (4.11.4)
# Requirement already satisfied: importlib-resources==5.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (5.7.1)
# Requirement already satisfied: install==1.3.5 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 60)) (1.3.5)
# Requirement already satisfied: ipykernel==6.13.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (6.13.0)
# Requirement already satisfied: ipython==8.3.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (8.3.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 64)) (7.7.1)
# Requirement already satisfied: jedi==0.18.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 65)) (0.18.1)
# Requirement already satisfied: jeepney==0.8.0 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 66)) (0.8.0)
# Requirement already satisfied: Jinja2==3.1.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 67)) (3.1.2)
# Requirement already satisfied: joblib==1.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 68)) (1.1.0)
# Requirement already satisfied: json5==0.9.8 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 69)) (0.9.8)
# Requirement already satisfied: jsonschema==4.5.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 70)) (4.5.1)
# Requirement already satisfied: jupyter==1.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 71)) (1.0.0)
# Requirement already satisfied: jupyter-client==7.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 72)) (7.3.1)
# Requirement already satisfied: jupyter-console==6.4.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 73)) (6.4.4)
# Requirement already satisfied: jupyter-core==4.10.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 74)) (4.10.0)
# Requirement already satisfied: jupyter-server==1.17.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 75)) (1.17.0)
# Requirement already satisfied: jupyterlab==3.4.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 76)) (3.4.2)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 77)) (0.2.2)
# Requirement already satisfied: jupyterlab-server==2.14.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 78)) (2.14.0)
# Requirement already satisfied: jupyterlab-widgets==1.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 79)) (1.1.1)
# Requirement already satisfied: kaggle==1.5.12 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 80)) (1.5.12)
# Requirement already satisfied: keras==2.9.0 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 81)) (2.9.0)
# Requirement already satisfied: keras-nightly==2.5.0.dev2021032900 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 82)) (2.5.0.dev2021032900)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 83)) (1.1.2)
# Requirement already satisfied: keyring==23.7.0 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 84)) (23.7.0)
# Requirement already satisfied: kiwisolver==1.4.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 85)) (1.4.3)
# Requirement already satisfied: libclang==14.0.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 86)) (14.0.1)
# Requirement already satisfied: lvis==0.5.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 87)) (0.5.3)
# Requirement already satisfied: lxml==4.9.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 88)) (4.9.0)
# Requirement already satisfied: Markdown==3.3.7 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 89)) (3.3.7)
# Requirement already satisfied: MarkupSafe==2.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 90)) (2.1.1)
# Requirement already satisfied: matplotlib==3.5.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 91)) (3.5.2)
# Requirement already satisfied: matplotlib-inline==0.1.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 92)) (0.1.3)
# Requirement already satisfied: mistune==0.8.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 93)) (0.8.4)
# Requirement already satisfied: mkl-fft==1.3.1 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 94)) (1.3.1)
# Requirement already satisfied: mkl-service==2.4.0 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 95)) (2.4.0)
# Requirement already satisfied: munkres==1.1.4 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 96)) (1.1.4)
# Requirement already satisfied: nbclassic==0.3.7 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 97)) (0.3.7)
# Requirement already satisfied: nbclient==0.6.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 98)) (0.6.3)
# Requirement already satisfied: nbconvert==6.5.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 99)) (6.5.0)
# Requirement already satisfied: nbformat==5.4.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 100)) (5.4.0)
# Requirement already satisfied: nest-asyncio==1.5.5 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 101)) (1.5.5)
# Requirement already satisfied: networkx==2.8.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 102)) (2.8.4)
# Requirement already satisfied: notebook==6.4.11 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 103)) (6.4.11)
# Requirement already satisfied: notebook-shim==0.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 104)) (0.1.0)
# Requirement already satisfied: oauth2client==4.1.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 106)) (4.1.3)
# Requirement already satisfied: oauthlib==3.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 107)) (3.2.0)
# Requirement already satisfied: opencv-python==4.6.0.66 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 108)) (4.6.0.66)
# Requirement already satisfied: opencv-python-headless==4.6.0.66 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 109)) (4.6.0.66)
# Requirement already satisfied: opt-einsum==3.3.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 110)) (3.3.0)
# Requirement already satisfied: packaging==21.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 111)) (21.3)
# Requirement already satisfied: pandas==1.3.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 112)) (1.3.3)
# Requirement already satisfied: pandocfilters==1.5.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 113)) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 114)) (0.8.3)
# Requirement already satisfied: pascal-voc-writer==0.1.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 115)) (0.1.4)
# Requirement already satisfied: pbr==5.9.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 116)) (5.9.0)
# Requirement already satisfied: pexpect==4.8.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 117)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 118)) (0.7.5)
# Requirement already satisfied: Pillow==9.0.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 119)) (9.0.1)
# Requirement already satisfied: pip==20.3.1 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 120)) (20.3.1)
# Requirement already satisfied: pkginfo==1.8.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 121)) (1.8.3)
# Requirement already satisfied: ply==3.11 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 122)) (3.11)
# Requirement already satisfied: portalocker==2.4.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 123)) (2.4.0)
# Requirement already satisfied: prometheus-client==0.14.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 124)) (0.14.1)
# Requirement already satisfied: promise==2.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 125)) (2.3)
# Requirement already satisfied: prompt-toolkit==3.0.29 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 126)) (3.0.29)
# Requirement already satisfied: protobuf==3.19.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (3.19.4)
# Requirement already satisfied: psutil==5.9.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 128)) (5.9.1)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 129)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 130)) (0.2.2)
# Requirement already satisfied: py-cpuinfo==8.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 131)) (8.0.0)
# Requirement already satisfied: pyarrow==5.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 132)) (5.0.0)
# Requirement already satisfied: pyasn1==0.4.8 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 133)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 134)) (0.2.8)
# Requirement already satisfied: pycocotools==2.0.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 135)) (2.0.4)
# Requirement already satisfied: pycparser==2.21 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 136)) (2.21)
# Requirement already satisfied: pyelftools==0.28 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 137)) (0.28)
# Requirement already satisfied: pygame==2.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 138)) (2.0.0)
# Requirement already satisfied: Pygments==2.12.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 139)) (2.12.0)
# Requirement already satisfied: pyparsing==3.0.9 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 140)) (3.0.9)
# Requirement already satisfied: PyQt5-sip==12.11.0 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 141)) (12.11.0)
# Requirement already satisfied: pyrsistent==0.18.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 142)) (0.18.1)
# Requirement already satisfied: PySocks==1.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 143)) (1.7.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 144)) (2.8.2)
# Requirement already satisfied: python-slugify==6.1.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 145)) (6.1.2)
# Requirement already satisfied: python-systemd==0.0.9 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 146)) (0.0.9)
# Requirement already satisfied: pytz==2022.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 147)) (2022.1)
# Requirement already satisfied: PyWavelets==1.3.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 148)) (1.3.0)
# Requirement already satisfied: PyYAML==5.4.1 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 149)) (5.4.1)
# Requirement already satisfied: pyzmq==23.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 150)) (23.0.0)
# Requirement already satisfied: qtconsole==5.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 151)) (5.3.1)
# Requirement already satisfied: QtPy==2.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 152)) (2.1.0)
# Requirement already satisfied: readme-renderer==35.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 153)) (35.0)
# Requirement already satisfied: regex==2022.6.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 154)) (2022.6.2)
# Requirement already satisfied: requests==2.27.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 155)) (2.27.1)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 156)) (1.3.1)
# Requirement already satisfied: requests-toolbelt==0.9.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 157)) (0.9.1)
# Requirement already satisfied: rfc3986==2.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 158)) (2.0.0)
# Requirement already satisfied: rich==12.4.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 159)) (12.4.4)
# Requirement already satisfied: rsa==4.8 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 160)) (4.8)
# Requirement already satisfied: sacrebleu==2.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 161)) (2.1.0)
# Requirement already satisfied: scikit-image==0.19.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 162)) (0.19.3)
# Requirement already satisfied: scikit-learn==1.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 163)) (1.1.1)
# Requirement already satisfied: scipy==1.8.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 164)) (1.8.1)
# Requirement already satisfied: SecretStorage==3.3.2 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 165)) (3.3.2)
# Requirement already satisfied: Send2Trash==1.8.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 166)) (1.8.0)
# Requirement already satisfied: sentencepiece==0.1.96 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 167)) (0.1.96)
# Requirement already satisfied: seqeval==1.2.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 168)) (1.2.2)
# Requirement already satisfied: setuptools==47.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 169)) (47.3.1)
# Requirement already satisfied: Shapely==1.8.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 170)) (1.8.2)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: sniffio==1.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 172)) (1.2.0)
# Requirement already satisfied: soupsieve==2.3.2.post1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 173)) (2.3.2.post1)
# Requirement already satisfied: stack-data==0.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 174)) (0.2.0)
# Requirement already satisfied: tabulate==0.8.10 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 175)) (0.8.10)
# Requirement already satisfied: tensorboard==2.9.1 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 176)) (2.9.1)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 177)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 178)) (1.8.1)
# Requirement already satisfied: tensorboardX==2.5 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 179)) (2.5)
# Requirement already satisfied: tensorflow==2.9.1 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 180)) (2.9.1)
# Requirement already satisfied: tensorflow-addons==0.17.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 181)) (0.17.1)
# Requirement already satisfied: tensorflow-datasets==4.6.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 182)) (4.6.0)
# Requirement already satisfied: tensorflow-estimator==2.9.0 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 183)) (2.9.0)
# Requirement already satisfied: tensorflow-hub==0.12.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 184)) (0.12.0)
# Requirement already satisfied: tensorflow-io==0.26.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 185)) (0.26.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.26.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 186)) (0.26.0)
# Requirement already satisfied: tensorflow-metadata==1.9.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 187)) (1.9.0)
# Requirement already satisfied: tensorflow-model-optimization==0.7.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 188)) (0.7.2)
# Requirement already satisfied: tensorflow-text==2.9.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 189)) (2.9.0)
# Requirement already satisfied: termcolor==1.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 190)) (1.1.0)
# Requirement already satisfied: terminado==0.15.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 191)) (0.15.0)
# Requirement already satisfied: testresources==2.0.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 192)) (2.0.1)
# Requirement already satisfied: text-unidecode==1.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 193)) (1.3)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 194)) (2.8.0.dev2021122109)
# Requirement already satisfied: tf-models-official==2.9.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 195)) (2.9.2)
# Requirement already satisfied: tf-slim==1.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 196)) (1.1.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 197)) (3.1.0)
# Requirement already satisfied: tifffile==2022.5.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 198)) (2022.5.4)
# Requirement already satisfied: tinycss2==1.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 199)) (1.1.1)
# Requirement already satisfied: toml==0.10.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 200)) (0.10.2)
# Requirement already satisfied: tornado==6.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 201)) (6.1)
# Requirement already satisfied: tqdm==4.64.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 202)) (4.64.0)
# Requirement already satisfied: traitlets==5.2.1.post0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 203)) (5.2.1.post0)
# Requirement already satisfied: twine==4.0.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 204)) (4.0.1)
# Requirement already satisfied: typeguard==2.13.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 205)) (2.13.3)
# Requirement already satisfied: typing-extensions==4.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 206)) (4.2.0)
# Requirement already satisfied: uritemplate==4.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 207)) (4.1.1)
# Requirement already satisfied: urllib3==1.26.9 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 208)) (1.26.9)
# Requirement already satisfied: wcwidth==0.2.5 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 209)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 210)) (0.5.1)
# Requirement already satisfied: websocket-client==1.3.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 211)) (1.3.2)
# Requirement already satisfied: Werkzeug==2.1.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 212)) (2.1.2)
# Requirement already satisfied: wheel==0.37.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 213)) (0.37.1)
# Requirement already satisfied: widgetsnbextension==3.6.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 214)) (3.6.1)
# Requirement already satisfied: wrapt==1.14.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 215)) (1.14.1)
# Requirement already satisfied: zipp==3.8.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 216)) (3.8.0)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: sniffio==1.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 172)) (1.2.0)
# Requirement already satisfied: idna==3.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (3.3)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: cffi==1.15.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (1.15.0)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: wheel==0.37.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 213)) (0.37.1)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: pyelftools==0.28 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 137)) (0.28)
# Requirement already satisfied: pytz==2022.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 147)) (2022.1)
# Requirement already satisfied: soupsieve==2.3.2.post1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 173)) (2.3.2.post1)
# Requirement already satisfied: webencodings==0.5.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 210)) (0.5.1)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: pycparser==2.21 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 136)) (2.21)
# Requirement already satisfied: cffi==1.15.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (1.15.0)
# Requirement already satisfied: requests==2.27.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 155)) (2.27.1)
# Requirement already satisfied: websocket-client==1.3.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 211)) (1.3.2)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: requests[socks]>=2.12.0 in /home/inteluser/.local/lib/python3.8/site-packages (from gdown==3.13.0->-r requirements.txt (line 43)) (2.27.1)
# Requirement already satisfied: filelock==3.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (3.7.1)
# Requirement already satisfied: tqdm==4.64.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 202)) (4.64.0)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: requests==2.27.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 155)) (2.27.1)
# Requirement already satisfied: googleapis-common-protos==1.56.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (1.56.3)
# Requirement already satisfied: google-auth==2.6.6 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.6.6)
# Requirement already satisfied: protobuf==3.19.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (3.19.4)
# Requirement already satisfied: google-api-core==2.8.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (2.8.2)
# Requirement already satisfied: google-auth==2.6.6 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.6.6)
# Requirement already satisfied: uritemplate==4.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 207)) (4.1.1)
# Requirement already satisfied: google-auth-httplib2==0.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (0.1.0)
# Requirement already satisfied: httplib2==0.20.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (0.20.4)
# Requirement already satisfied: cachetools==5.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (5.1.0)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 134)) (0.2.8)
# Requirement already satisfied: rsa==4.8 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 160)) (4.8)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: google-auth==2.6.6 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.6.6)
# Requirement already satisfied: httplib2==0.20.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (0.20.4)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: google-auth==2.6.6 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.6.6)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 156)) (1.3.1)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: protobuf==3.19.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (3.19.4)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: pyparsing==3.0.9 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 140)) (3.0.9)
# Requirement already satisfied: Pillow==9.0.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 119)) (9.0.1)
# Requirement already satisfied: scikit-image==0.19.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 162)) (0.19.3)
# Requirement already satisfied: imageio==2.19.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (2.19.3)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: matplotlib==3.5.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 91)) (3.5.2)
# Requirement already satisfied: opencv-python==4.6.0.66 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 108)) (4.6.0.66)
# Requirement already satisfied: scipy==1.8.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 164)) (1.8.1)
# Requirement already satisfied: Shapely==1.8.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 170)) (1.8.2)
# Requirement already satisfied: Pillow==9.0.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 119)) (9.0.1)
# Requirement already satisfied: zipp==3.8.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 216)) (3.8.0)
# Requirement already satisfied: zipp==3.8.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 216)) (3.8.0)
# Requirement already satisfied: jupyter-client==7.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 72)) (7.3.1)
# Requirement already satisfied: traitlets==5.2.1.post0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 203)) (5.2.1.post0)
# Requirement already satisfied: tornado==6.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 201)) (6.1)
# Requirement already satisfied: packaging==21.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 111)) (21.3)
# Requirement already satisfied: ipython==8.3.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (8.3.0)
# Requirement already satisfied: nest-asyncio==1.5.5 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 101)) (1.5.5)
# Requirement already satisfied: psutil==5.9.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 128)) (5.9.1)
# Requirement already satisfied: matplotlib-inline==0.1.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 92)) (0.1.3)
# Requirement already satisfied: debugpy==1.6.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (1.6.0)
# Requirement already satisfied: pexpect==4.8.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 117)) (4.8.0)
# Requirement already satisfied: Pygments==2.12.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 139)) (2.12.0)
# Requirement already satisfied: backcall==0.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: setuptools==47.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 169)) (47.3.1)
# Requirement already satisfied: matplotlib-inline==0.1.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 92)) (0.1.3)
# Requirement already satisfied: stack-data==0.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 174)) (0.2.0)
# Requirement already satisfied: traitlets==5.2.1.post0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 203)) (5.2.1.post0)
# Requirement already satisfied: jedi==0.18.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 65)) (0.18.1)
# Requirement already satisfied: pickleshare==0.7.5 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 118)) (0.7.5)
# Requirement already satisfied: decorator==5.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (5.1.1)
# Requirement already satisfied: prompt-toolkit==3.0.29 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 126)) (3.0.29)
# Requirement already satisfied: ipykernel==6.13.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (6.13.0)
# Requirement already satisfied: jupyterlab-widgets==1.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 79)) (1.1.1)
# Requirement already satisfied: traitlets==5.2.1.post0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 203)) (5.2.1.post0)
# Requirement already satisfied: widgetsnbextension==3.6.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 214)) (3.6.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (0.2.0)
# Requirement already satisfied: ipython==8.3.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (8.3.0)
# Requirement already satisfied: parso==0.8.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 114)) (0.8.3)
# Requirement already satisfied: MarkupSafe==2.1.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 90)) (2.1.1)
# Requirement already satisfied: attrs==21.4.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (21.4.0)
# Requirement already satisfied: pyrsistent==0.18.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 142)) (0.18.1)
# Requirement already satisfied: importlib-resources==5.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (5.7.1)
# Requirement already satisfied: qtconsole==5.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 151)) (5.3.1)
# Requirement already satisfied: nbconvert==6.5.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 99)) (6.5.0)
# Requirement already satisfied: notebook==6.4.11 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 103)) (6.4.11)
# Requirement already satisfied: jupyter-console==6.4.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 73)) (6.4.4)
# Requirement already satisfied: ipykernel==6.13.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (6.13.0)
# Requirement already satisfied: ipywidgets==7.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 64)) (7.7.1)
# Requirement already satisfied: traitlets==5.2.1.post0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 203)) (5.2.1.post0)
# Requirement already satisfied: nest-asyncio==1.5.5 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 101)) (1.5.5)
# Requirement already satisfied: pyzmq==23.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 150)) (23.0.0)
# Requirement already satisfied: entrypoints==0.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (0.4)
# Requirement already satisfied: tornado==6.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 201)) (6.1)
# Requirement already satisfied: jupyter-core==4.10.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 74)) (4.10.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 144)) (2.8.2)
# Requirement already satisfied: jupyter-client==7.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 72)) (7.3.1)
# Requirement already satisfied: ipykernel==6.13.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (6.13.0)
# Requirement already satisfied: ipython==8.3.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (8.3.0)
# Requirement already satisfied: prompt-toolkit==3.0.29 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 126)) (3.0.29)
# Requirement already satisfied: Pygments==2.12.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 139)) (2.12.0)
# ...
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 177)) (0.6.1)
# Requirement already satisfied: requests==2.27.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 155)) (2.27.1)
# Requirement already satisfied: absl-py==1.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: protobuf==3.19.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (3.19.4)
# Requirement already satisfied: google-auth==2.6.6 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.6.6)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 178)) (1.8.1)
# Requirement already satisfied: wheel==0.37.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 213)) (0.37.1)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: protobuf==3.19.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (3.19.4)
# Requirement already satisfied: keras==2.9.0 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 81)) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.26.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 186)) (0.26.0)
# Requirement already satisfied: packaging==21.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 111)) (21.3)
# Requirement already satisfied: absl-py==1.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: libclang==14.0.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 86)) (14.0.1)
# Requirement already satisfied: opt-einsum==3.3.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 110)) (3.3.0)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: wrapt==1.14.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 215)) (1.14.1)
# Requirement already satisfied: tensorboard==2.9.1 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 176)) (2.9.1)
# Requirement already satisfied: protobuf==3.19.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (3.19.4)
# Requirement already satisfied: gast==0.4.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (0.4.0)
# Requirement already satisfied: setuptools==47.3.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 169)) (47.3.1)
# Requirement already satisfied: tensorflow-estimator==2.9.0 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 183)) (2.9.0)
# Requirement already satisfied: typing-extensions==4.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 206)) (4.2.0)
# Requirement already satisfied: astunparse==1.6.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 83)) (1.1.2)
# Requirement already satisfied: grpcio==1.34.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (1.34.0)
# Requirement already satisfied: flatbuffers==1.12 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (1.12)
# Requirement already satisfied: h5py==3.7.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 53)) (3.7.0)
# Requirement already satisfied: termcolor==1.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 190)) (1.1.0)
# Requirement already satisfied: google-pasta==0.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (0.2.0)
# Requirement already satisfied: typeguard==2.13.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 205)) (2.13.3)
# Requirement already satisfied: packaging==21.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 111)) (21.3)
# Requirement already satisfied: termcolor==1.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 190)) (1.1.0)
# Requirement already satisfied: tensorflow-metadata==1.9.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 187)) (1.9.0)
# Requirement already satisfied: requests==2.27.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 155)) (2.27.1)
# Requirement already satisfied: etils[epath] in /home/inteluser/.local/lib/python3.8/site-packages (from tensorflow-datasets==4.6.0->-r requirements.txt (line 182)) (0.6.0)
# Requirement already satisfied: tqdm==4.64.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 202)) (4.64.0)
# Requirement already satisfied: absl-py==1.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: protobuf==3.19.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (3.19.4)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: toml==0.10.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 200)) (0.10.2)
# Requirement already satisfied: importlib-resources==5.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (5.7.1)
# Requirement already satisfied: promise==2.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 125)) (2.3)
# Requirement already satisfied: dill==0.3.5.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (0.3.5.1)
# Requirement already satisfied: protobuf==3.19.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (3.19.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.26.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 186)) (0.26.0)
# Requirement already satisfied: absl-py==1.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: googleapis-common-protos==1.56.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (1.56.3)
# Requirement already satisfied: protobuf==3.19.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 127)) (3.19.4)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: dm-tree==0.1.7 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (0.1.7)
# Requirement already satisfied: tensorflow-hub==0.12.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 184)) (0.12.0)
# Requirement already satisfied: tensorflow==2.9.1 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 180)) (2.9.1)
# Requirement already satisfied: tornado==6.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 201)) (6.1)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 129)) (0.7.0)
# Requirement already satisfied: pbr==5.9.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 116)) (5.9.0)
# Requirement already satisfied: Cython==0.29.30 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (0.29.30)
# Requirement already satisfied: pandas==1.3.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 112)) (1.3.3)
# Requirement already satisfied: psutil==5.9.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 128)) (5.9.1)
# Requirement already satisfied: six==1.16.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 171)) (1.16.0)
# Requirement already satisfied: tensorflow==2.9.1 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 180)) (2.9.1)
# Requirement already satisfied: oauth2client==4.1.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 106)) (4.1.3)
# Requirement already satisfied: kaggle==1.5.12 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 80)) (1.5.12)
# Requirement already satisfied: tensorflow-datasets==4.6.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 182)) (4.6.0)
# Requirement already satisfied: google-api-python-client==2.52.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (2.52.0)
# Requirement already satisfied: pycocotools==2.0.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 135)) (2.0.4)
# Requirement already satisfied: matplotlib==3.5.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 91)) (3.5.2)
# Requirement already satisfied: tensorflow-hub==0.12.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 184)) (0.12.0)
# Requirement already satisfied: py-cpuinfo==8.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 131)) (8.0.0)
# Requirement already satisfied: seqeval==1.2.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 168)) (1.2.2)
# Requirement already satisfied: tensorflow-addons==0.17.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 181)) (0.17.1)
# Requirement already satisfied: tf-slim==1.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 196)) (1.1.0)
# Requirement already satisfied: PyYAML==5.4.1 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 149)) (5.4.1)
# Requirement already satisfied: tensorflow-text==2.9.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 189)) (2.9.0)
# Requirement already satisfied: gin-config==0.5.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (0.5.0)
# Requirement already satisfied: sacrebleu==2.1.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 161)) (2.1.0)
# Requirement already satisfied: scipy==1.8.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 164)) (1.8.1)
# Requirement already satisfied: tensorflow-model-optimization==0.7.2 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 188)) (0.7.2)
# Requirement already satisfied: sentencepiece==0.1.96 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 167)) (0.1.96)
# Requirement already satisfied: opencv-python-headless==4.6.0.66 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 109)) (4.6.0.66)
# Requirement already satisfied: Pillow==9.0.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 119)) (9.0.1)
# Requirement already satisfied: absl-py==1.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: webencodings==0.5.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 210)) (0.5.1)
# Requirement already satisfied: pkginfo==1.8.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 121)) (1.8.3)
# Requirement already satisfied: rich==12.4.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 159)) (12.4.4)
# Requirement already satisfied: requests-toolbelt==0.9.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 157)) (0.9.1)
# Requirement already satisfied: urllib3==1.26.9 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 208)) (1.26.9)
# Requirement already satisfied: importlib-metadata==4.11.4 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (4.11.4)
# Requirement already satisfied: rfc3986==2.0.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 158)) (2.0.0)
# Requirement already satisfied: keyring==23.7.0 in /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages (from -r requirements.txt (line 84)) (23.7.0)
# Requirement already satisfied: requests==2.27.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 155)) (2.27.1)
# Requirement already satisfied: readme-renderer==35.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 153)) (35.0)
# Requirement already satisfied: notebook==6.4.11 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 103)) (6.4.11)
# Requirement already satisfied: zipp==3.8.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 216)) (3.8.0)
# Requirement already satisfied: importlib-resources==5.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (5.7.1)
# Requirement already satisfied: etils[epy] in /home/inteluser/.local/lib/python3.8/site-packages (from etils[epath]->tensorflow-datasets==4.6.0->-r requirements.txt (line 182)) (0.6.0)
# Requirement already satisfied: typing-extensions==4.2.0 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 206)) (4.2.0)
# Requirement already satisfied: certifi==2022.5.18.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (2022.5.18.1)
# Requirement already satisfied: idna==3.3 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (3.3)
# Requirement already satisfied: charset-normalizer==2.0.12 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (2.0.12)
# Requirement already satisfied: urllib3==1.26.9 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 208)) (1.26.9)
# Requirement already satisfied: PySocks==1.7.1 in /home/inteluser/.local/lib/python3.8/site-packages (from -r requirements.txt (line 143)) (1.7.1)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.2
#     Uninstalling numpy-1.23.2:
#       Successfully uninstalled numpy-1.23.2
# Successfully installed numpy-1.23.1
# WARNING: You are using pip version 20.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/inteluser/anaconda3/envs/openfl/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
np.random.seed(0)
import os
# disable GPUs due to Tensoflow not supporting CUDA 11
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %% [markdown]
# # Connect to the Federation

# %%
# Create a federation
from openfl.interface.interactive_api.federation import Federation

# please use the same identificator that was used in signed certificate
cliend_id = 'frontend'

# 1) Run with API layer - Director mTLS
# If the user wants to enable mTLS their must provide CA root chain, and signed key pair to the federation interface
# cert_chain = 'cert/root_ca.crt'
# API_certificate = 'cert/frontend.crt'
# API_private_key = 'cert/frontend.key'

# federation = Federation(client_id='frontend', director_node_fqdn='localhost', director_port='50051', disable_tls=False,
#                        cert_chain=cert_chain, api_cert=API_certificate, api_private_key=API_private_key)

# --------------------------------------------------------------------------------------------------------------------

# 2) Run with TLS disabled (trusted environment)
# Federation can also determine local fqdn automatically
federation = Federation(client_id='frontend', director_node_fqdn='localhost', director_port='50051', tls=False)

# %%
shard_registry = federation.get_shard_registry()
shard_registry
# Out:
# {'env_one': {'shard_info': node_info {
#     name: "env_one"
#   }
#   shard_description: "Dataset from env_one by CARLA"
#   sample_shape: "600"
#   sample_shape: "800"
#   sample_shape: "3"
#   target_shape: "1",
#   'is_online': True,
#   'is_experiment_running': False,
#   'last_updated': '2022-08-15 19:53:18',
#   'current_time': '2022-08-15 19:53:37',
#   'valid_duration': seconds: 120,
#   'experiment_name': 'ExperimentName Mock'},
#  'env_two': {'shard_info': node_info {
#     name: "env_two"
#   }
#   shard_description: "Dataset from env_two by CARLA"
#   sample_shape: "600"
#   sample_shape: "800"
#   sample_shape: "3"
#   target_shape: "1",
#   'is_online': True,
#   'is_experiment_running': False,
#   'last_updated': '2022-08-15 19:52:42',
#   'current_time': '2022-08-15 19:53:37',
#   'valid_duration': seconds: 120,
#   'experiment_name': 'ExperimentName Mock'}}

# %%
federation.target_shape
# Out:
# ['1']

# %%
# First, request a dummy_shard_desc that holds information about the federated dataset 
dummy_shard_desc = federation.get_dummy_shard_descriptor(size=10)
sample, target = dummy_shard_desc.get_dataset(dataset_type='')[0]
f"Sample shape: {sample.shape}, target shape: {target.shape}"
# Out:
# 'Sample shape: (600, 800, 3), target shape: (1,)'

# %% [markdown]
# ## Creating a FL experiment using Interactive API

# %%
from openfl.interface.interactive_api.experiment import TaskInterface, DataInterface, ModelInterface, FLExperiment
# Out:
# 2022-08-15 19:53:38.281210: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH:
# 2022-08-15 19:53:38.281231: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### Register dataset

# %%
from tensorflow.keras.utils import Sequence

class DataGenerator(Sequence):

    def __init__(self, train_dataset, train_labels):
        self.train_dataset = train_dataset
        self.train_labels = train_labels

    def __getitem__(self):
        return self.train_dataset, self.train_labels

# Now you can implement you data loaders using dummy_shard_desc
class CARLAFedDataset(DataInterface):

    def __init__(self, train_dataset=[], val_dataset=[], train_val_split=0.8, **kwargs):
        super().__init__(**kwargs)
        self.train_dataset = train_dataset
        self.val_dataset = val_dataset
        self.train_val_split = train_val_split

    @property
    def shard_descriptor(self):
        return self._shard_descriptor

    @shard_descriptor.setter
    def shard_descriptor(self, shard_descriptor):
        """
        Describe per-collaborator procedures or sharding.

        This method will be called during a collaborator initialization.
        Local shard_descriptor will be set by Envoy.
        """
        self._shard_descriptor = shard_descriptor

    def __getitem__(self, index):
        return self.shard_descriptor[index]

    def __len__(self):
        return len(self.shard_descriptor)

    def get_train_loader(self):
        """
        Output of this method will be provided to tasks with optimizer in contract
        """
        print('tttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttt')
        # if self.kwargs['train_bs']:
        #     batch_size = self.kwargs['train_bs']
        # else:
        #     batch_size = 64

        self.train_dataset, _ = self.shard_descriptor.get_dataset('train', labels=LABELS)
        # train_valid_split = int(self.train_val_split*len(train_dataset))
        # np.random.shuffle(train_dataset)
        # self.train_dataset = train_dataset[:train_valid_split]
        # self.val_dataset = train_dataset[train_valid_split:]
        return self.train_dataset

    def get_valid_loader(self):
        """
        Output of this method will be provided to tasks without optimizer in contract
        """
        print('vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv')
#         if self.kwargs['valid_bs']:
#             batch_size = self.kwargs['valid_bs']
#         else:
#             batch_size = 512

#         self.val_dataset, self.val_labels = self.shard_descriptor.get_dataset('val', self.train_val_split, labels=LABELS)
        self.val_dataset, _ = self.shard_descriptor.get_dataset('val', labels=LABELS)
        return self.val_dataset
        # return DataGenerator(self.val_dataset, batch_size=batch_size)

    def get_train_data_size(self):
        """
        Information for aggregation
        """
        return len(self.train_dataset)

    def get_valid_data_size(self):
        """
        Information for aggregation
        """
        return len(self.val_dataset)

# %% [markdown]
# ### Describe a model and optimizer

# %%
import tensorflow as tf
print('TensorFlow', tf.__version__)
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Reshape, Activation, Conv2D, Input, MaxPooling2D, BatchNormalization, Flatten, Dense, Lambda
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.layers import concatenate
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
import imgaug as ia
from tqdm import tqdm
from imgaug import augmenters as iaa
import pickle
import os, cv2
from preprocessing import BatchGenerator
from utils import decode_netout, draw_boxes

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"

# %matplotlib inline
# Out:
# TensorFlow 2.9.1

# %%
LABELS = ['vehicle']

IMAGE_H, IMAGE_W = 416, 416
GRID_H,  GRID_W  = 13 , 13
BOX              = 5
CLASS            = len(LABELS)
CLASS_WEIGHTS    = np.ones(CLASS, dtype='float32')
OBJ_THRESHOLD    = 0.3#0.5
NMS_THRESHOLD    = 0.3#0.45
ANCHORS          = [0.57273, 0.677385, 1.87446, 2.06253, 3.33843, 5.47434, 7.88282, 3.52778, 9.77052, 9.16828]

NO_OBJECT_SCALE  = 1.0
OBJECT_SCALE     = 5.0
COORD_SCALE      = 1.0
CLASS_SCALE      = 0.0

BATCH_SIZE       = 16
WARM_UP_BATCHES  = 0
TRUE_BOX_BUFFER  = 10

# %%
input_image = Input(shape=(IMAGE_H, IMAGE_W, 3))
true_boxes  = Input(shape=(1, 1, 1, TRUE_BOX_BUFFER , 4))

# Layer 1
x = Conv2D(16, (3,3), strides=(1,1), padding='same', name='conv_1', use_bias=False)(input_image)
x = BatchNormalization(name='norm_1')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2 - 5
for i in range(0,4):
    x = Conv2D(32*(2**i), (3,3), strides=(1,1), padding='same', name='conv_' + str(i+2), use_bias=False)(x)
    x = BatchNormalization(name='norm_' + str(i+2))(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

# Layer 6
x = Conv2D(512, (3,3), strides=(1,1), padding='same', name='conv_6', use_bias=False)(x)
x = BatchNormalization(name='norm_6')(x)
x = LeakyReLU(alpha=0.1)(x)
x = MaxPooling2D(pool_size=(2, 2), strides=(1,1), padding='same')(x)

# Layer 7 - 8
for i in range(0,2):
    x = Conv2D(1024, (3,3), strides=(1,1), padding='same', name='conv_' + str(i+7), use_bias=False)(x)
    x = BatchNormalization(name='norm_' + str(i+7))(x)
    x = LeakyReLU(alpha=0.1)(x)

feature_extractor = Model(input_image, x)
feature_extractor.load_weights('tiny_yolo_backend.h5')

# Layer 9
x = Conv2D(BOX * (4 + 1 + CLASS), (1,1), strides=(1,1), padding='same', name='conv_9')(x)
output = Reshape((GRID_H, GRID_W, BOX, 4 + 1 + CLASS))(x)

# small hack to allow true_boxes to be registered when Keras build the model 
# for more information: https://github.com/fchollet/keras/issues/2790
output = Lambda(lambda args: args[0])([output, true_boxes])

model = Model([input_image, true_boxes], output)
# Out:
# 2022-08-15 19:53:40.250788: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-08-15 19:53:40.250823: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: netcompute-testbed-node1
# 2022-08-15 19:53:40.250831: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: netcompute-testbed-node1
# 2022-08-15 19:53:40.250963: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 510.85.2
# 2022-08-15 19:53:40.250987: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 510.85.2
# 2022-08-15 19:53:40.250994: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 510.85.2
# 2022-08-15 19:53:40.251441: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 416, 416, 3  0           []
#                                 )]
#
#  conv_1 (Conv2D)                (None, 416, 416, 16  432         ['input_1[0][0]']
#                                 )
#
#  norm_1 (BatchNormalization)    (None, 416, 416, 16  64          ['conv_1[0][0]']
#                                 )
#
#  leaky_re_lu (LeakyReLU)        (None, 416, 416, 16  0           ['norm_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 208, 208, 16  0           ['leaky_re_lu[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 208, 208, 32  4608        ['max_pooling2d[0][0]']
#                                 )
#
#  norm_2 (BatchNormalization)    (None, 208, 208, 32  128         ['conv_2[0][0]']
#                                 )
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 208, 208, 32  0           ['norm_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 104, 104, 32  0          ['leaky_re_lu_1[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 104, 104, 64  18432       ['max_pooling2d_1[0][0]']
#                                 )
#
#  norm_3 (BatchNormalization)    (None, 104, 104, 64  256         ['conv_3[0][0]']
#                                 )
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 104, 104, 64  0           ['norm_3[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 52, 52, 64)  0           ['leaky_re_lu_2[0][0]']
#
#  conv_4 (Conv2D)                (None, 52, 52, 128)  73728       ['max_pooling2d_2[0][0]']
#
#  norm_4 (BatchNormalization)    (None, 52, 52, 128)  512         ['conv_4[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 52, 52, 128)  0           ['norm_4[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 26, 26, 128)  0          ['leaky_re_lu_3[0][0]']
#
#  conv_5 (Conv2D)                (None, 26, 26, 256)  294912      ['max_pooling2d_3[0][0]']
#
#  norm_5 (BatchNormalization)    (None, 26, 26, 256)  1024        ['conv_5[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 26, 26, 256)  0           ['norm_5[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 13, 13, 256)  0          ['leaky_re_lu_4[0][0]']
#
#  conv_6 (Conv2D)                (None, 13, 13, 512)  1179648     ['max_pooling2d_4[0][0]']
#
#  norm_6 (BatchNormalization)    (None, 13, 13, 512)  2048        ['conv_6[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 13, 13, 512)  0           ['norm_6[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 13, 13, 512)  0          ['leaky_re_lu_5[0][0]']
#
#  conv_7 (Conv2D)                (None, 13, 13, 1024  4718592     ['max_pooling2d_5[0][0]']
#                                 )
#
#  norm_7 (BatchNormalization)    (None, 13, 13, 1024  4096        ['conv_7[0][0]']
#                                 )
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 13, 13, 1024  0           ['norm_7[0][0]']
#                                 )
#
#  conv_8 (Conv2D)                (None, 13, 13, 1024  9437184     ['leaky_re_lu_6[0][0]']
#                                 )
#
#  norm_8 (BatchNormalization)    (None, 13, 13, 1024  4096        ['conv_8[0][0]']
#                                 )
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 13, 13, 1024  0           ['norm_8[0][0]']
#                                 )
#
#  conv_9 (Conv2D)                (None, 13, 13, 30)   30750       ['leaky_re_lu_7[0][0]']
#
#  reshape (Reshape)              (None, 13, 13, 5, 6  0           ['conv_9[0][0]']
#                                 )
#
#  input_2 (InputLayer)           [(None, 1, 1, 1, 10  0           []
#                                 , 4)]
#
#  lambda (Lambda)                (None, 13, 13, 5, 6  0           ['reshape[0][0]',
#                                 )                                 'input_2[0][0]']
#
# ==================================================================================================
# Total params: 15,770,510
# Trainable params: 15,764,398
# Non-trainable params: 6,112
# __________________________________________________________________________________________________

# %%
layer   = model.layers[-4] # the last convolutional layer
weights = layer.get_weights()

new_kernel = np.random.normal(size=weights[0].shape)/(GRID_H*GRID_W)
new_bias   = np.random.normal(size=weights[1].shape)/(GRID_H*GRID_W)

layer.set_weights([new_kernel, new_bias])

# %%
def custom_loss(b_batch, y_true, y_pred):
    tf.to_float = lambda x: tf.cast(x, tf.float32)
    y_true = tf.to_float(y_true)
    mask_shape = tf.shape(y_true)[:4]
    cell_x = tf.to_float(tf.reshape(tf.tile(tf.range(GRID_W), [GRID_H]), (1, GRID_H, GRID_W, 1, 1)))
    cell_y = tf.transpose(cell_x, (0,2,1,3,4))

    cell_grid = tf.tile(tf.concat([cell_x,cell_y], -1), [BATCH_SIZE, 1, 1, 5, 1])
    
    coord_mask = tf.zeros(mask_shape)
    conf_mask  = tf.zeros(mask_shape)
    class_mask = tf.zeros(mask_shape)
    
    seen = tf.Variable(0.)
    total_recall = tf.Variable(0.)
    
    """
    Adjust prediction
    """
    ### adjust x and y      
    pred_box_xy = tf.sigmoid(y_pred[..., :2]) + cell_grid
    ### adjust w and h
    pred_box_wh = tf.exp(y_pred[..., 2:4]) * np.reshape(ANCHORS, [1,1,1,BOX,2])
    
    ### adjust confidence
    pred_box_conf = tf.sigmoid(y_pred[..., 4])
    ### adjust class probabilities
    pred_box_class = y_pred[..., 5:]
    
    """
    Adjust ground truth
    """
    ### adjust x and y
    true_box_xy = y_true[..., 0:2] # relative position to the containing cell
    
    ### adjust w and h
    true_box_wh = y_true[..., 2:4] # number of cells accross, horizontally and vertically
    
    ### adjust confidence
    true_wh_half = true_box_wh / 2.
    true_mins    = true_box_xy - true_wh_half
    true_maxes   = true_box_xy + true_wh_half
    
    pred_wh_half = pred_box_wh / 2.
    pred_mins    = pred_box_xy - pred_wh_half
    pred_maxes   = pred_box_xy + pred_wh_half       
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
    pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)
    
    true_box_conf = iou_scores * y_true[..., 4]
    
    ### adjust class probabilities
    true_box_class = tf.argmax(y_true[..., 5:], -1)
    
    """
    Determine the masks
    """
    ### coordinate mask: simply the position of the ground truth boxes (the predictors)
    coord_mask = tf.expand_dims(y_true[..., 4], axis=-1) * COORD_SCALE
    
    ### confidence mask: penelize predictors + penalize boxes with low IOU
    # penalize the confidence of the boxes, which have IOU with some ground truth box < 0.6
    # true_xy = true_boxes[..., 0:2]
    # true_wh = true_boxes[..., 2:4]
    b_batch = tf.to_float(b_batch)
    true_xy = b_batch[..., 0:2]
    true_wh = b_batch[..., 2:4]
    
    true_wh_half = true_wh / 2.
    true_mins    = true_xy - true_wh_half
    true_maxes   = true_xy + true_wh_half
    
    pred_xy = tf.expand_dims(pred_box_xy, 4)
    pred_wh = tf.expand_dims(pred_box_wh, 4)
    
    pred_wh_half = pred_wh / 2.
    pred_mins    = pred_xy - pred_wh_half
    pred_maxes   = pred_xy + pred_wh_half    
    
    intersect_mins  = tf.maximum(pred_mins,  true_mins)
    intersect_maxes = tf.minimum(pred_maxes, true_maxes)
    intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
    intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
    
    true_areas = true_wh[..., 0] * true_wh[..., 1]
    pred_areas = pred_wh[..., 0] * pred_wh[..., 1]

    union_areas = pred_areas + true_areas - intersect_areas
    iou_scores  = tf.truediv(intersect_areas, union_areas)

    best_ious = tf.reduce_max(iou_scores, axis=4)
    conf_mask = conf_mask + tf.to_float(best_ious < 0.6) * (1 - y_true[..., 4]) * NO_OBJECT_SCALE
    
    # penalize the confidence of the boxes, which are reponsible for corresponding ground truth box
    conf_mask = conf_mask + y_true[..., 4] * OBJECT_SCALE
    
    
    ### class mask: simply the position of the ground truth boxes (the predictors)
    class_mask = y_true[..., 4] * tf.gather(CLASS_WEIGHTS, true_box_class) * CLASS_SCALE       
    
    """
    Warm-up training
    """
    no_boxes_mask = tf.to_float(coord_mask < COORD_SCALE/2.)
    seen = tf.compat.v1.assign_add(seen, 1.)
    
    true_box_xy, true_box_wh, coord_mask = tf.cond(tf.less(seen, WARM_UP_BATCHES), 
                          lambda: [true_box_xy + (0.5 + cell_grid) * no_boxes_mask, 
                                   true_box_wh + tf.ones_like(true_box_wh) * np.reshape(ANCHORS, [1,1,1,BOX,2]) * no_boxes_mask, 
                                   tf.ones_like(coord_mask)],
                          lambda: [true_box_xy, 
                                   true_box_wh,
                                   coord_mask])
    
    """
    Finalize the loss
    """
    nb_coord_box = tf.reduce_sum(tf.to_float(coord_mask > 0.0))
    nb_conf_box  = tf.reduce_sum(tf.to_float(conf_mask  > 0.0))
    nb_class_box = tf.reduce_sum(tf.to_float(class_mask > 0.0))
    
    true_box_xy = tf.to_float(true_box_xy)
    coord_mask = tf.to_float(coord_mask)
    
    loss_xy    = tf.reduce_sum(tf.square(true_box_xy-pred_box_xy)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_wh    = tf.reduce_sum(tf.square(true_box_wh-pred_box_wh)     * coord_mask) / (nb_coord_box + 1e-6) / 2.
    loss_conf  = tf.reduce_sum(tf.square(true_box_conf-pred_box_conf) * conf_mask)  / (nb_conf_box  + 1e-6) / 2.
    loss_class = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=true_box_class, logits=pred_box_class)
    loss_class = tf.reduce_sum(loss_class * class_mask) / (nb_class_box + 1e-6)
    
    loss = loss_xy + loss_wh + loss_conf + loss_class
    
#     nb_true_box = tf.reduce_sum(y_true[..., 4])
#     nb_pred_box = tf.reduce_sum(tf.to_float(true_box_conf > 0.5) * tf.to_float(pred_box_conf > 0.3))

#     """
#     Debugging code
#     """    
#     current_recall = nb_pred_box/(nb_true_box + 1e-6)
#     total_recall = tf.compat.v1.assign_add(total_recall, current_recall) 

    # loss = tf.Print(loss, [tf.zeros((1))], message='Dummy Line \t', summarize=1000)
    # loss = tf.Print(loss, [loss_xy], message='Loss XY \t', summarize=1000)
    # loss = tf.Print(loss, [loss_wh], message='Loss WH \t', summarize=1000)
    # loss = tf.Print(loss, [loss_conf], message='Loss Conf \t', summarize=1000)
    # loss = tf.Print(loss, [loss_class], message='Loss Class \t', summarize=1000)
    # loss = tf.Print(loss, [loss], message='Total Loss \t', summarize=1000)
    # loss = tf.Print(loss, [current_recall], message='Current Recall \t', summarize=1000)
    # loss = tf.Print(loss, [total_recall/seen], message='Average Recall \t', summarize=1000)
    # tf.print(loss)
    
    return loss

# %%
generator_config = {
    'IMAGE_H'         : IMAGE_H, 
    'IMAGE_W'         : IMAGE_W,
    'GRID_H'          : GRID_H,  
    'GRID_W'          : GRID_W,
    'BOX'             : BOX,
    'LABELS'          : LABELS,
    'CLASS'           : len(LABELS),
    'ANCHORS'         : ANCHORS,
    'BATCH_SIZE'      : BATCH_SIZE,
    'TRUE_BOX_BUFFER' : 10,
}

# %%
def normalize(image):
    return image / 255.

# %%
optimizer = Adam(lr=1e-4)
# optimizer = Adam(lr=0.5e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
#optimizer = SGD(lr=1e-4, decay=0.0005, momentum=0.9)
#optimizer = RMSprop(lr=1e-4, rho=0.9, epsilon=1e-08, decay=0.0)
# Out:
# /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
fed_dataset = CARLAFedDataset(train_bs=64, valid_bs=512)

# %% [markdown]
# ### Define and register FL tasks

# %%
import matplotlib.pyplot as plt
import os
from utils import evaluate

TI = TaskInterface()

# https://www.tensorflow.org/guide/keras/customizing_what_happens_in_fit
@TI.register_fl_task(model='model', data_loader='train_loader', device='device', optimizer='optimizer')

def train(model, train_loader, device, optimizer):
    # train_dataset, train_labels = train_loader
    train_batch = BatchGenerator(train_loader, generator_config, norm=normalize, jitter=False)

    # Iterate over the batches of the dataset.
    batch_loss = []
    for step, (x_batch_train, y_batch_train) in enumerate(train_batch):
        y = tf.convert_to_tensor(y_batch_train)
        _, b_batch = x_batch_train
        b_batch = tf.convert_to_tensor(b_batch)
        with tf.GradientTape() as tape:
            y_pred = model(x_batch_train, training=True)  # Forward pass
            # Compute the loss value
            # (the loss function is configured in `compile()`)
            loss = custom_loss(b_batch, y, y_pred)

        # Compute gradients
        trainable_vars = model.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        optimizer.apply_gradients(zip(gradients, trainable_vars))
        # Update metrics
        batch_loss.append(loss)
    train_loss = sum(batch_loss)/len(batch_loss)
    print('Training loss over epoch: %.4f' % (float(train_loss)))
    return {'train_loss': train_loss}


@TI.register_fl_task(model='model', data_loader='val_loader', device='device')
def validate(model, val_loader, device=''):
    # val_dataset, val_labels = val_loader
    val_batch = BatchGenerator(val_loader, generator_config, norm=normalize, jitter=False)
    
    ############################################
    # Compute mAP on the validation set
    ############################################
    average_precisions = evaluate(model, val_batch)     

    # print evaluation
    for label, average_precision in average_precisions.items():
        print(LABELS[label], '{:.4f}'.format(average_precision))
    mAP = sum(average_precisions.values()) / len(average_precisions)
    return {'mAP': tf.convert_to_tensor(mAP)}

    # for x_batch_val, y_batch_val in val_loader:
    #     y = tf.convert_to_tensor(y_batch_val)
    #     # Compute predictions
    #     y_pred = model(x_batch_val, training=False)
    #     # Update the metrics.
    #     val_acc_metric.update_state(y, y_pred)
    # val_acc = val_acc_metric.result()
    # val_acc_metric.reset_states()
    # return {'validation_accuracy': val_acc}

# %% [markdown]
# #### Register model

# %%
from copy import deepcopy

framework_adapter = 'openfl.plugins.frameworks_adapters.keras_adapter.FrameworkAdapterPlugin'
MI = ModelInterface(model=model, optimizer=optimizer, framework_plugin=framework_adapter)
# Save the initial model state
initial_model = deepcopy(model)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 9). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://92a8ee7c-3d64-4219-9cad-758dfa3f9bea/assets
# INFO:tensorflow:Assets written to: ram://92a8ee7c-3d64-4219-9cad-758dfa3f9bea/assets
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## Time to start a federated learning experiment

# %%
# create an experimnet in federation
experiment_name = 'CARLA_experiment'
fl_experiment = FLExperiment(federation=federation, experiment_name=experiment_name)

# %%
# If I use autoreload I got a pickling error
# The following command zips the workspace and python requirements to be transfered to collaborator nodes
fl_experiment.start(model_provider=MI, 
                    task_keeper=TI,
                    data_loader=fed_dataset,
                    rounds_to_train=70,
                    opt_treatment='RESET')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 9). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://dbf42ad2-6cf8-4391-b1f6-4deefc2fb813/assets
# INFO:tensorflow:Assets written to: ram://dbf42ad2-6cf8-4391-b1f6-4deefc2fb813/assets
# /home/inteluser/anaconda3/envs/openfl/lib/python3.8/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# WARNING:openfl.federated.task.task_runner:tried to remove tensor: __opt_state_needed not present in the tensor dict
# WARNING:openfl.interface.interactive_api.experiment:tried to remove tensor: __opt_state_needed not present in the tensor dict

# %%
# If user want to stop IPython session, then reconnect and check how experiment is going 
# fl_experiment.restore_experiment_state(MI)

fl_experiment.stream_metrics()

# %% [markdown]
# ## Testing the best model

# %%
# !pip install -r ../envoy/sd_requirements.txt

# %%
import sys
sys.path.insert(1, '../envoy')

# %%
from shard_descriptor import NextWordShardDescriptor

# https://www.gutenberg.org/files/2892/2892-h/2892-h.htm
fed_dataset = NextWordSD(train_bs=64, valid_bs=512, train_val_split=0)
fed_dataset.shard_descriptor = NextWordShardDescriptor(title='Irish Fairy Tales', author='James Stephens')

# %%
best_model = fl_experiment.get_best_model()

# We remove data from director
fl_experiment.remove_experiment_data()

# Validating initial model
validate(initial_model, fed_dataset.get_valid_loader())

# %%
# Validating trained model
validate(best_model, fed_dataset.get_valid_loader())
